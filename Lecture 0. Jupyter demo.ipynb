# %% [markdown]
# # Start
# *This* is **text**

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E88-ACC7
#
#  Directory of C:\Users\Mariia\Documents\Jupyter\python-course
#
# 14.02.2024  21:34    <DIR>          .
# 14.02.2024  21:34    <DIR>          ..
# 14.02.2024  20:54    <DIR>          .ipynb_checkpoints
# 14.02.2024  21:34            57ÿ318 Lecture 0. Jupyter demo.ipynb
#                1 File(s)         57ÿ318 bytes
#                3 Dir(s)  136ÿ385ÿ486ÿ848 bytes free

# %%
import time

for i in range(7):
    time.sleep(5)

# %%
s = 'Hello world!'

# %%
print(s)
# Out:
# Hello world!

# %%
a = 'Hello everyone!'

# %%
a.lower()
# Out:
# 'hello everyone!'

# %%
pwd
# Out:
# 'C:\\Users\\Mariia\\Documents\\Jupyter\\python-course'

# %% [markdown]
# ## Continue

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(50)))
